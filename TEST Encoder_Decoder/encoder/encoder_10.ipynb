# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Input, Model
def lightweight_block(input_tensor):
    # Depthwise convolution (preserves input dimensions)
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(input_tensor)
    
    # 1x1 convolution to mix channels and increase to 8
    x = layers.Conv2D(8, kernel_size=1, padding='same')(x)
    
    # 3x3 convolution block with BatchNorm and ReLU
    x = layers.Conv2D(8, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "A")(x)
    
    return x

def downsample_block(input_tensor):
    # Depthwise convolution with stride=2 for downsampling
    x = layers.DepthwiseConv2D(kernel_size=3, strides=2, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    
    # 1x1 convolution for channel mixing
    x = layers.Conv2D(input_tensor.shape[-1], kernel_size=1, padding='same')(x)
    
    # Second depthwise convolution
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "B")(x)
    
    return x

def double_channels_same_dim_block(input_tensor):
    # Depthwise convolution
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    
    # 1x1 convolution to double the channels
    out_channels = input_tensor.shape[-1] * 2
    x = layers.Conv2D(out_channels, kernel_size=1, padding='same')(x)
    
    # Second depthwise convolution
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "C")(x)
    
    return x

def downsample_same_channels_block(input_tensor):
    # Depthwise conv with stride=2 for downsampling
    x = layers.DepthwiseConv2D(kernel_size=3, strides=2, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    
    # 1x1 conv for channel mixing (same channels)
    channels = input_tensor.shape[-1]
    x = layers.Conv2D(channels, kernel_size=1, padding='same')(x)
    
    # Second depthwise conv
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "D")(x)
    
    return x

def double_channels_block(input_tensor):
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    out_channels = input_tensor.shape[-1] * 2
    x = layers.Conv2D(out_channels, kernel_size=1, padding='same')(x)

    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "E")(x)

    return x

def downsample_block_same_channels(input_tensor):
    x = layers.DepthwiseConv2D(kernel_size=3, strides=2, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    channels = input_tensor.shape[-1]
    x = layers.Conv2D(channels, kernel_size=1, padding='same')(x)

    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "F")(x)

    return x

def double_channels_block_22(input_tensor):
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    out_channels = input_tensor.shape[-1] * 2
    x = layers.Conv2D(out_channels, kernel_size=1, padding='same')(x)

    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "G")(x)

    return x

def downsample_block_2(input_tensor):
    x = layers.DepthwiseConv2D(kernel_size=3, strides=2, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    channels = input_tensor.shape[-1]
    x = layers.Conv2D(channels, kernel_size=1, padding='same')(x)

    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "H")(x)

    return x

def double_channels_block_2(input_tensor):
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    out_channels = input_tensor.shape[-1] * 2
    x = layers.Conv2D(out_channels, kernel_size=1, padding='same')(x)

    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "I")(x)

    return x


#################################### upsampling and concat blocks ####################################

def fuse_and_double_channels_block(low_res_input, high_res_input):
    # Upsample the low-res input (11, 19, 128) to match high-res spatial dims (22, 38)
    low_res_upsampled = layers.UpSampling2D(size=(2, 2), interpolation='bilinear')(low_res_input)
    
    # Concatenate along channel axis -> shape becomes (22, 38, 64 + 128 = 192)
    x = layers.Concatenate(axis=-1)([high_res_input, low_res_upsampled])
    
    # Standard Conv2D to reduce channels from 192 to 96
    x = layers.Conv2D(96, kernel_size=3, padding='same')(x)
    
    # Depthwise separable processing
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(96, kernel_size=1, padding='same')(x)

    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name = "J")(x)

    return x

def fuse_without_conv_block(low_res_input, high_res_input):
    # Upsample the low-res input (22, 38, 96) to match high-res spatial dims (44, 76)
    low_res_upsampled = layers.UpSampling2D(size=(2, 2), interpolation='bilinear')(low_res_input)
    
    # Concatenate along channel axis -> shape becomes (44, 76, 96 + 32 = 128)
    x = layers.Concatenate(axis=-1)([high_res_input, low_res_upsampled])
    
    # Depthwise conv + BN + ReLU
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # 1x1 conv for channel mixing to reduce channels to 40
    x = layers.Conv2D(40, kernel_size=1, padding='same')(x)
    
    # Another depthwise conv + BN + ReLU
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name="K")(x)
    
    return x

def fuse_and_adjust_channels_block(low_res_input, high_res_input):
    # Upsample the low-res input (44, 76, 32) to match high-res spatial dims (88, 152)
    low_res_upsampled = layers.UpSampling2D(size=(2, 2), interpolation='bilinear')(low_res_input)
    
    # Concatenate along channel axis -> shape becomes (88, 152, 32 + 16 = 48)
    x = layers.Concatenate(axis=-1)([high_res_input, low_res_upsampled])
    
    # Standard Conv2D to increase channels from 48 to 58
    x = layers.Conv2D(58, kernel_size=3, padding='same')(x)
    
    # Depthwise separable processing
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(58, kernel_size=1, padding='same')(x)

    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name="L")(x)

    return x

def fuse_without_conv_block_v2(low_res_input, high_res_input):
    # Upsample the low-res input (88, 152, 58) to match high-res spatial dims (176, 304)
    low_res_upsampled = layers.UpSampling2D(size=(2, 2), interpolation='bilinear')(low_res_input)
    
    # Concatenate along channel axis -> shape becomes (176, 304, 58 + 8 = 66)
    x = layers.Concatenate(axis=-1)([high_res_input, low_res_upsampled])
    
    # Depthwise conv + BN + ReLU
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # 1x1 conv for channel mixing to get output channels = 64
    x = layers.Conv2D(64, kernel_size=1, padding='same')(x)

    # Another depthwise conv + BN + ReLU
    x = layers.DepthwiseConv2D(kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(name="out")(x)

    return x

# %%
inputlayer = layers.Input(shape= (176,304,3))
skip_connections = []
outputs = lightweight_block(inputlayer)
skip_connections.append(outputs)

outputs = downsample_block(outputs)
outputs = double_channels_same_dim_block(outputs)
skip_connections.append(outputs)

outputs = downsample_same_channels_block(outputs)
outputs = double_channels_block(outputs)
skip_connections.append(outputs)

outputs = downsample_block_same_channels(outputs)
outputs = double_channels_block_22(outputs)
skip_connections.append(outputs)

outputs = downsample_block_2(outputs)
outputs = double_channels_block_2(outputs)

A, C, E, G = skip_connections
#concate I(==outputs) and H 
J = fuse_and_double_channels_block(outputs, G)
#concate J and E
K = fuse_without_conv_block(J, E)
#concate K and C
L = fuse_and_adjust_channels_block(K, C)
# concate L and A
out = fuse_without_conv_block_v2(L, A)

model = Model(inputs = inputlayer, outputs = out)
model.summary()
# Out:
# Model: "functional_35"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_41      │ (None, 176, 304,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 176, 304,  │         30 │ input_layer_41[0… │
# │ (DepthwiseConv2D)   │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_286 (Conv2D) │ (None, 176, 304,  │         32 │ depthwise_conv2d… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_287 (Conv2D) │ (None, 176, 304,  │        584 │ conv2d_286[0][0]  │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 176, 304,  │         32 │ conv2d_287[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ A (ReLU)            │ (None, 176, 304,  │          0 │ batch_normalizat… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 88, 152,   │         80 │ A[0][0]           │
# │ (DepthwiseConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 152,   │         32 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_267 (ReLU)    │ (None, 88, 152,   │          0 │ batch_normalizat… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_288 (Conv2D) │ (None, 88, 152,   │         72 │ re_lu_267[0][0]   │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 88, 152,   │         80 │ conv2d_288[0][0]  │
# │ (DepthwiseConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 152,   │         32 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ B (ReLU)            │ (None, 88, 152,   │          0 │ batch_normalizat… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 88, 152,   │         80 │ B[0][0]           │
# │ (DepthwiseConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 152,   │         32 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_268 (ReLU)    │ (None, 88, 152,   │          0 │ batch_normalizat… │
# │                     │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_289 (Conv2D) │ (None, 88, 152,   │        144 │ re_lu_268[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 88, 152,   │        160 │ conv2d_289[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 152,   │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ C (ReLU)            │ (None, 88, 152,   │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 44, 76,    │        160 │ C[0][0]           │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 76,    │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_269 (ReLU)    │ (None, 44, 76,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_290 (Conv2D) │ (None, 44, 76,    │        272 │ re_lu_269[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 44, 76,    │        160 │ conv2d_290[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 76,    │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ D (ReLU)            │ (None, 44, 76,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 44, 76,    │        160 │ D[0][0]           │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 76,    │         64 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_270 (ReLU)    │ (None, 44, 76,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_291 (Conv2D) │ (None, 44, 76,    │        544 │ re_lu_270[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 44, 76,    │        320 │ conv2d_291[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 76,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ E (ReLU)            │ (None, 44, 76,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 22, 38,    │        320 │ E[0][0]           │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 38,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_271 (ReLU)    │ (None, 22, 38,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_292 (Conv2D) │ (None, 22, 38,    │      1,056 │ re_lu_271[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 22, 38,    │        320 │ conv2d_292[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 38,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ F (ReLU)            │ (None, 22, 38,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 22, 38,    │        320 │ F[0][0]           │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 38,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_272 (ReLU)    │ (None, 22, 38,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_293 (Conv2D) │ (None, 22, 38,    │      2,112 │ re_lu_272[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 22, 38,    │        640 │ conv2d_293[0][0]  │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 38,    │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ G (ReLU)            │ (None, 22, 38,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 11, 19,    │        640 │ G[0][0]           │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 19,    │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_273 (ReLU)    │ (None, 11, 19,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_294 (Conv2D) │ (None, 11, 19,    │      4,160 │ re_lu_273[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 11, 19,    │        640 │ conv2d_294[0][0]  │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 19,    │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ H (ReLU)            │ (None, 11, 19,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 11, 19,    │        640 │ H[0][0]           │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 19,    │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_274 (ReLU)    │ (None, 11, 19,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_295 (Conv2D) │ (None, 11, 19,    │      8,320 │ re_lu_274[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 11, 19,    │      1,280 │ conv2d_295[0][0]  │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 11, 19,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ I (ReLU)            │ (None, 11, 19,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_18    │ (None, 22, 38,    │          0 │ I[0][0]           │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 22, 38,    │          0 │ G[0][0],          │
# │ (Concatenate)       │ 192)              │            │ up_sampling2d_18… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_296 (Conv2D) │ (None, 22, 38,    │    165,984 │ concatenate_19[0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 22, 38,    │        960 │ conv2d_296[0][0]  │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 38,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_275 (ReLU)    │ (None, 22, 38,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_297 (Conv2D) │ (None, 22, 38,    │      9,312 │ re_lu_275[0][0]   │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 22, 38,    │        960 │ conv2d_297[0][0]  │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 22, 38,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ J (ReLU)            │ (None, 22, 38,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_19    │ (None, 44, 76,    │          0 │ J[0][0]           │
# │ (UpSampling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 44, 76,    │          0 │ E[0][0],          │
# │ (Concatenate)       │ 128)              │            │ up_sampling2d_19… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 44, 76,    │      1,280 │ concatenate_20[0… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 76,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_276 (ReLU)    │ (None, 44, 76,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_298 (Conv2D) │ (None, 44, 76,    │      5,160 │ re_lu_276[0][0]   │
# │                     │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 44, 76,    │        400 │ conv2d_298[0][0]  │
# │ (DepthwiseConv2D)   │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 44, 76,    │        160 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ K (ReLU)            │ (None, 44, 76,    │          0 │ batch_normalizat… │
# │                     │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_20    │ (None, 88, 152,   │          0 │ K[0][0]           │
# │ (UpSampling2D)      │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 88, 152,   │          0 │ C[0][0],          │
# │ (Concatenate)       │ 56)               │            │ up_sampling2d_20… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_299 (Conv2D) │ (None, 88, 152,   │     29,290 │ concatenate_21[0… │
# │                     │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 88, 152,   │        580 │ conv2d_299[0][0]  │
# │ (DepthwiseConv2D)   │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 152,   │        232 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_277 (ReLU)    │ (None, 88, 152,   │          0 │ batch_normalizat… │
# │                     │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_300 (Conv2D) │ (None, 88, 152,   │      3,422 │ re_lu_277[0][0]   │
# │                     │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 88, 152,   │        580 │ conv2d_300[0][0]  │
# │ (DepthwiseConv2D)   │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 88, 152,   │        232 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ L (ReLU)            │ (None, 88, 152,   │          0 │ batch_normalizat… │
# │                     │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_21    │ (None, 176, 304,  │          0 │ L[0][0]           │
# │ (UpSampling2D)      │ 58)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 176, 304,  │          0 │ A[0][0],          │
# │ (Concatenate)       │ 66)               │            │ up_sampling2d_21… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 176, 304,  │        660 │ concatenate_22[0… │
# │ (DepthwiseConv2D)   │ 66)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 176, 304,  │        264 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 66)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_278 (ReLU)    │ (None, 176, 304,  │          0 │ batch_normalizat… │
# │                     │ 66)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_301 (Conv2D) │ (None, 176, 304,  │      4,288 │ re_lu_278[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4… │ (None, 176, 304,  │        640 │ conv2d_301[0][0]  │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 176, 304,  │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out (ReLU)          │ (None, 176, 304,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 251,698 (983.20 KB)
#  Trainable params: 249,270 (973.71 KB)
#  Non-trainable params: 2,428 (9.48 KB)

# %%
import time
for i in range(10):
    input_tensor = tf.random.normal([1,176,304,3])
    start  = time.time()
    output_data = model(input_tensor)
    print(f"time for operations is : {(time.time() - start)*1000.:2f} ms")
# Out:
# time for operations is : 147.927046 ms
# time for operations is : 62.347889 ms
# time for operations is : 58.679104 ms
# time for operations is : 56.204796 ms
# time for operations is : 59.333086 ms
# time for operations is : 55.888176 ms
# time for operations is : 55.975199 ms
# time for operations is : 58.487177 ms
# time for operations is : 61.177254 ms
# time for operations is : 57.781935 ms

# %% [markdown]
# ## tflite model

# %%
import numpy as np

# Assume build_model() is already defined and model is created
input_shape = (176, 608, 3)
optimized_model = Model(inputs = inputlayer, outputs = out)


# Step 1: Convert the Keras model to TensorFlow Lite
def convert_to_tflite(keras_model, tflite_model_path='encoder_10.tflite'):
    # Create a converter object from the Keras model
    converter = tf.lite.TFLiteConverter.from_keras_model(keras_model)
    # Optional optimizations (comment out if not needed)
    # converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()
    
    # Save the converted model to disk
    with open(tflite_model_path, 'wb') as f:
        f.write(tflite_model)
    print(f"TFLite model saved to: {tflite_model_path}")

convert_to_tflite(model)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/xb/sshzwv1128l88chp71np05t40000gn/T/tmptq44mj8p/assets
# INFO:tensorflow:Assets written to: /var/folders/xb/sshzwv1128l88chp71np05t40000gn/T/tmptq44mj8p/assets
# Saved artifact at '/var/folders/xb/sshzwv1128l88chp71np05t40000gn/T/tmptq44mj8p'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 176, 304, 3), dtype=tf.float32, name='keras_tensor_1652')
# Output Type:
#   TensorSpec(shape=(None, 176, 304, 64), dtype=tf.float32, name=None)
# Captures:
#   12920981648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12978692816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   12920985488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286475088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286473936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286467984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286469328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286470864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286469136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286470096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286473552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286460112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286474128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286466448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286471056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286473168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286472208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286462800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286468752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286474512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286468944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286474704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286464336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286465296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286472400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286461456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286467792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286470672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286467408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286459152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286469520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286472976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286471440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286469712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286474896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286471824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286471248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286465104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286472592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286468560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286470480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286470288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286472016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286467024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286473744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286472784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286467600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286465488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286468368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286464912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286467216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286465680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286466832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286466256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286462032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286461840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286465872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286468176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286462416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286466064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286463376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286466640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286473360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286458960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286459344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286461648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286462608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286461264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286461072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286462224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286464720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286463952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286462992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286459728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286464144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286460880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286459920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286471632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286469904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286459536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286460304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6286474320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267568976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267577616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267575696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267576080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267573584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267582032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267582608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267583760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267580880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267580688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267575888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267578768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267580496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267582992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267576656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267576464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267576848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267578576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267577424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267582416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267573200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267574160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267581264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267568208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267573008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267570896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267575120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267573776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267581840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267583568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267572240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267575312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267572816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267573392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267578384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267571472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267574928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267574736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267581072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267569168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267578960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267582224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267577040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267579920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267571856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267572048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267577808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267579344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267576272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267579536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267579728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267574544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267577232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267578000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267572624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267578192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267573968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267580304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283107536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283114448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6267579152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283106384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283106576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283115984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283115600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283102736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283105616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283108496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283106960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283105232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283108112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283107152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283116368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283106192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283113296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283115024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283114064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283109264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283106000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283103888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283115792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283112528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283113680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283106768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283113872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283102544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283115216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283107344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283111376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283114640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283105808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283114832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283114256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283107728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283111184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283116176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283112912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283113104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6283105424: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved to: encoder_10.tflite
# W0000 00:00:1748701326.215673 1755961 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1748701326.215683 1755961 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# 2025-05-31 19:52:06.215795: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /var/folders/xb/sshzwv1128l88chp71np05t40000gn/T/tmptq44mj8p
# 2025-05-31 19:52:06.219973: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-05-31 19:52:06.219980: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /var/folders/xb/sshzwv1128l88chp71np05t40000gn/T/tmptq44mj8p
# 2025-05-31 19:52:06.272595: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-05-31 19:52:06.557895: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /var/folders/xb/sshzwv1128l88chp71np05t40000gn/T/tmptq44mj8p
# 2025-05-31 19:52:06.644964: I tensorflow/cc/saved_model/loader.cc:462] SavedModel load for tags { serve }; Status: success: OK. Took 429168 microseconds.

# %%
import time


def run_tflite_inference_with_timing(tflite_model_path='encoder_10.tflite', input_shape=(176,304,3), num_iterations=10):
    interpreter = tf.lite.Interpreter(model_path=tflite_model_path, num_threads=4)
    interpreter.allocate_tensors()
    
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    for i in range(num_iterations):
        input_data = np.random.random_sample((1,) + input_shape).astype(np.float32)
        interpreter.set_tensor(input_details[0]['index'], input_data)
        
        start_time = time.time()
        interpreter.invoke()
        end_time = time.time()
        
        output_data = interpreter.get_tensor(output_details[0]['index'])
        
        inference_time = (end_time - start_time) * 1000  # milliseconds
        print(f"Inference {i+1}: output shape = {output_data.shape}, time = {inference_time:.2f} ms")

# Run inference with timing
run_tflite_inference_with_timing()
# Out:
# Inference 1: output shape = (1, 176, 304, 64), time = 23.54 ms
# Inference 2: output shape = (1, 176, 304, 64), time = 16.70 ms
# Inference 3: output shape = (1, 176, 304, 64), time = 10.61 ms
# Inference 4: output shape = (1, 176, 304, 64), time = 11.28 ms
# Inference 5: output shape = (1, 176, 304, 64), time = 9.89 ms
# Inference 6: output shape = (1, 176, 304, 64), time = 11.64 ms
# Inference 7: output shape = (1, 176, 304, 64), time = 10.10 ms
# Inference 8: output shape = (1, 176, 304, 64), time = 10.41 ms
# Inference 9: output shape = (1, 176, 304, 64), time = 9.93 ms
# Inference 10: output shape = (1, 176, 304, 64), time = 10.09 ms
